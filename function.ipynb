# %%
 #function is a reusable block of code  that performs a specific task when called. 
 # functions are useful to orginize code ,make it reuasble and reduce redundancy.
 #you define a function using def keyword followed by the function name, parenthesses and a colon

# %%
a , b = 1 , 2
print(a + b)

c, d = 3, 4
print(c + d)
#to reduce the repeatancy and to orginise we use def
# Out:
# 3
# 7

# %%
def great ():
    print("hello good mornting!")
great()
great()
great()
great()
great()
# Out:
# hello good mornting!
# hello good mornting!
# hello good mornting!
# hello good mornting!
# hello good mornting!

# %%
def marriage():
    print("boy married a girl")
marriage()
marriage()
marriage()
marriage()
# Out:
# boy married a girl
# boy married a girl
# boy married a girl
# boy married a girl

# %%
def marriage(boy , girl):
    print(f"boy is {boy}")
    print(f"girl is {girl}")
    print(f"{boy} is married to  {girl}")
marriage("manik","chandramukhi")   
marriage ("manik","nagavalli")
# Out:
# boy is manik
# girl is chandramukhi
# manik is married to  chandramukhi
# boy is manik
# girl is nagavalli
# manik is married to  nagavalli

# %%
def marks(phy , chy, bio):
    print(f"phy in {phy}")
    print(f"chy in {chy}")
    print(f"bio is {bio}")
marks("10", "20","30") 
marks ("1", "2","3")
marks("a+","b+","c+")
# Out:
# phy in 10
# chy in 20
# bio is 30
# phy in 1
# chy in 2
# bio is 3
# phy in a+
# chy in b+
# bio is c+

# %%
def agreement (buyer , seller, broker):
    print(f"first party is buyer = {buyer}")
    print(f"second party is seller = {seller}")
    print(f"third party is broker = {broker}")

agreement("manik", "abhi", "taufiq")
agreement("nagraj","nagamani","deepu")
# Out:
# first party is buyer = manik
# second party is seller = abhi
# third party is broker = taufiq
# first party is buyer = nagraj
# second party is seller = nagamani
# third party is broker = deepu

# %%
def fight(boy ,otherboy):
   
    print(f"{otherboy} smaked {boy}")
    print(f" {boy} got smaked by {otherboy}")
    print(f"{boy} fought with {otherboy}")

fight("taufiq","deepu") 
fight("abhi","nagu")
# Out:
# deepu smaked taufiq
#  taufiq got smaked by deepu
# taufiq fought with deepu
# nagu smaked abhi
#  abhi got smaked by nagu
# abhi fought with nagu

# %%
def process_numbers(a, b):
    
    def add():
        return a + b
    
    def multiply():
        return a * b
    
    print("Sum:", add())
    print("Product:", multiply())

process_numbers(3, 4)
process_numbers(1,10)
# Out:
# Sum: 7
# Product: 12
# Sum: 11
# Product: 10

# %%
def login(password):
    def check_password():
     return password == "1234"
    if check_password():
       print("granted")
    else:
       print("dennied")
login("2345") 
login("1234")
# Out:
# dennied
# granted

# %%
def marks(phy,chy,bio):
    def obtained_marks():
        return phy == 100 and chy == 200 and bio == 300
    if obtained_marks():
        print("wooww")
    else:
        print("whyyyy")

marks(10,20,30)
marks(100,200,300)
# Out:
# whyyyy
# wooww

# %%
def tables (num):
 i = 0
 while (i < 11):
    print(f"{num}*{i} = {num * i}")
    i = i + 1
tables(3)
tables (7)
# Out:
# 3*0 = 0
# not found...
# 3*1 = 3
# not found...
# 3*2 = 6
# not found...
# 3*3 = 9
# not found...
# 3*4 = 12
# not found...
# 3*5 = 15
# not found...
# 3*6 = 18
# not found...
# 3*7 = 21
# not found...
# 3*8 = 24
# not found...
# 3*9 = 27
# not found...
# 3*10 = 30
# not found...
# 7*0 = 0
# not found...
# 7*1 = 7
# not found...
# 7*2 = 14
# not found...
# 7*3 = 21
# not found...
# 7*4 = 28
# not found...
# 7*5 = 35
# not found...
# 7*6 = 42
# not found...
# 7*7 = 49
# not found...
# 7*8 = 56
# not found...
# 7*9 = 63
# not found...
# 7*10 = 70
# not found...

# %%
def marriage (boy , girl ):
    print(f"boy is a {boy}")
    print(f"girl is a {girl}")
    print(f"{boy}  married {girl}")
marriage("manik","nagavalli")  
marriage ("taufiq","simran")
# Out:
# boy is a manik
# girl is a nagavalli
# manik  married nagavalli
# boy is a taufiq
# girl is a simran
# taufiq  married simran

# %%
# default case: girl in case girl
def marriage (boy , girl="girl" ):
    print(f"boy is a {boy}")
    print(f"girl is a {girl}")
    print(f"{boy}  married {girl}")
marriage("manik")  
marriage ("taufiq")
# Out:
# boy is a manik
# girl is a girl
# manik  married girl
# boy is a taufiq
# girl is a girl
# taufiq  married girl

# %%
num = int(input("enter a number(1,2,3):"))
list = ["bjp", "conj","jds"]

if (num == 1):
    print("in voted for bjp")
elif(num == 2):
    print("i voted for conj")
elif(num == 3):
    print("i voted for jds")
else:
    print("NOTA")
# Out:
# NOTA

# %%
#when we give input to the function so the output given is return
def func(num):
    print(str(num)*3)
    print(num*3)
func(2)
# Out:
# 222
# 6

# %%
def func(num):
    return (int(str(num)*5))#convert string to number bcz int cant add to string
a = 100                     #return is the real output
b = func(4)                 #print is given to shoew  the output
c = a + b
print(c)
# Out:
# 44544

# %%
def add_numbers( a ,b):
    return a+b
    print("the sum is:",result)
add_numbers(4,5)
# Out:
# 9

# %%
def func():
    x = "manik" #local variable 
    print("hello manik")
    print(y)

y = "manu" #global var

print(y)
# Out:
# manu

# %%
def add_number(a , b):
    return (a+b)
    print("the sum is :",result)
add_number(3,4)
# Out:
# 7

# %%
def movies(kgf , bahuballi, rrr):
    print(f"first best movie {kgf}")
    print(f"second best movie {bahuballi}")
    print(f"third best movie {rrr}")
movies("garuda gamana vrishabha vahana ", "kantara","hero")   
movies("i", "robo","indian")
# Out:
# first best movie garuda gamana vrishabha vahana
# second best movie kantara
# third best movie hero
# first best movie i
# second best movie robo
# third best movie indian

# %%
def movies(kgf , bahuballi, rrr):
    print(f"first best movie {kgf}")
    print(f"second best movie {bahuballi}")
    print(f"third best movie {rrr}")
    

   
 
movies("1","2","3")  
movies("marri","ranjhana","fighter")
# Out:
# first best movie 1
# second best movie 2
# third best movie 3
# first best movie marri
# second best movie ranjhana
# third best movie fighter

# %%
def is_even(num):
    if (num % 2 == 0):
        return "even"
    else:
        return "odd"
    
for i in range (1 ,11):
      x = is_even(i)
      print(x,[i])
# Out:
# odd [1]
# even [2]
# odd [3]
# even [4]
# odd [5]
# even [6]
# odd [7]
# even [8]
# odd [9]
# even [10]

# %%
def is_sum(a, b):
    print("sum is:",a+b)
    
is_sum(3,4)
# Out:
# sum is: 7

# %%
def sum_is(a, b):
    return a+b
    
x=sum_is(3,4)
print("sum_is:",x)
# Out:
# sum_is: 7

# %%
def sum (a, b):
    return a+ b
a = int(input("enter a number:"))
b = int(input("enter a number:"))

x = sum (a , b)
print("sum=",x)
# Out:
# sum= 5

# %%
def given_num(digits):
    if(digits % 2 == 0):
        return "even"
    else:
        return "odd"
     
given_num(100)
# Out:
# 'even'

# %%
def even_odd(a):
     a = int(input("enter a :"))
     if (a % 2 == 0):
        print("even")
     else:
        print("odd")
    
   
even_odd(a)
# Out:
# odd

# %%
def max(a, b, c):
   if (a>b and a>c):
      print("a is grater:",)
   elif( b>c):
      print("b is grater:",)
   else:
        print("c is grater:",)
max(4, 5, 7)
# Out:
# c is grater: [10]

# %%
def max(a, b, c):
   if (a>b and a>c):
      return a
   elif( b>c):
      return b
   else:
        return c
max(4, 5, 7)
# Out:
# 7

# %%
def summmation(my_list):
    return(my_list)
my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9, 0]
sum = 0
for i in my_list:
    sum = sum +i

    
print(sum)
# Out:
# 45

# %%
def summmation(my_list):
    return(my_list)
my_list = [1, 2, 3, 4, 5, 6, 7, 8, 9, ]
fact = 1
for i in my_list:
    fact = fact*i
    print(fact)
# Out:
# 1
# 2
# 6
# 24
# 120
# 720
# 5040
# 40320
# 362880
