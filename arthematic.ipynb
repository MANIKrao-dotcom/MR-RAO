# %%
a = 50
b = 3
print("the value of", a ,"+",3,"is:",a+b)
print("the value of", a ,"-",3,"is:",a-b)
print("the value of", a ,"*",3,"is:",a*b)
print("the value of", a ,"/",3,"is:",a/b)
print("the value of", a ,"//",3,"is:",a//b)
print("the value of", a ,"**",3,"is:",a**b)
# Out:
# the value of 50 + 3 is: 53
# the value of 50 - 3 is: 47
# the value of 50 * 3 is: 150
# the value of 50 / 3 is: 16.666666666666668
# the value of 50 // 3 is: 16
# the value of 50 ** 3 is: 125000

# %%
print(15/6)
print(5%6)
print(15//6)
print(5**3)
print(5+6)
print(15-6)
print(15*6)
# Out:
# 2.5
# 5
# 2
# 125
# 11
# 9
# 90

# %%
a=10
b=20
c=30
d=50
print("multiplaction:",a*b*c*d)
# Out:
# multiplaction: 300000

# %%
a = 10
b = 20
print("sum =",a+b)
# Out:
# sum = 30

# %%
 # comparisional operators 
a = 40
b = 50
print(a == b)
print(a > b)
print(a < b)
print(a != b)
print(a < 30)
print(b > 10)
# Out:
# False
# False
# True
# True
# False
# True

# %%
#logical operators
#and : returns true if both conditions are true
#or : returns true if at least one condition is true
#not : reverse the logical state of its operrand (true becomes false, and false became true)
a = 2
b = 4
c = 5
print (a > b and b > c)
print( a < b and a < b )

print(a < b or b > c)

print(not (a > 10))#it should be false but as we used not operator sor it gives true for false
# Out:
# False
# True
# True
# True

# %%
#membership operators
list = [1, 2, 3, 4, 5, 6]
print(3 in list)
print(8 not in list)
# Out:
# True
# True

# %%
string = "manik"
print("n" in string)
print("z" in string)
print("z" not in string)
# Out:
# True
# False
# True
