# %%
str1 = "this is a string"
str2 = "and in am workijng on it" #for next line shift use\n and for space between them use\t

print(str1+str2)

str1 = "this is a string\n and i am working on it\t\t for some time"
print(str1)
# Out:
# this is a stringand in am workijng on it
# this is a string
#  and i am working on it		 for some time

# %%
str1 = "manik"
str2 = "rao"
print(str1 + str2)#or we can store as a final_string i.e 
                  #final_str = (str1+str2)
# Out:
# manikrao

# %%
#to see the length of string
name = "manik"
len1 = len(name)
print(len1)

name2 = "rao"
len2 = len(name2)
print(len2)


final_name=(name +name2)
print(final_name)

final_name = len(name + name2)
print (final_name)
# Out:
# 5
# 3
# manikrao
# 8

# %%
#indexing = giving a position number to a specific characters in string
#it starts with 0
#help to acess the characters
name = "manik"
ch = name[3]
print(ch)

name2 = "manik rao"
ch1 = name2[5]
print(ch1)

name = "manik rao"
ch = name[6]
print(ch)
# Out:
# i
#
# r

# %%
name2 = "manik rao"
ch1 = name2[5]
print(ch1)

# %%
#slicing = acessing part of a string
name = "manikrao"
print(name[1:6])


name = "manik rao"
print(name[3:7])

name = "manik rao"
print(name[:7])#if nothing is given in the start of ratio it itself take as starting point i.e 0
 
name = "manik rao"
print(name[0:]) #if nothing is given in the end of ratio it itself take ass end of the string

name = "manik rao"
print(name[0:len(name)])# it gives same as above
# Out:
# anikr
# ik r
# manik r
# manik rao
# manik rao

# %%
#1) to check wether the words are
str = "i am studing python from gcu"
print(str.endswith("app")) #returns true if string ends with substr

#2) to capitalize the 1st letter from a string
str2 = "i am studing python from gcu"
print(str2.capitalize())#capitalizes 1st char
print(str2)#it wont work when we run it again so for that

str = "i am studing python from gcu"
str = (str.capitalize())#now this modification is dtored in old string
print(str)
# Out:
# False
# I am studing python from gcu
# i am studing python from gcu
# I am studing python from gcu

# %%
#3)replacing charcater inside the string
str = "i am studing python from gcu"
print(str.replace("a" ,"o"))

str = "i am studing python from gcu"
print(str.replace("python","java"))

str = "i am studing python from gcu"
print(str.replace("i am ","you are "))
# Out:
# i om studing python from gcu
# i am studing java from gcu
# you are studing python from gcu

# %%
#4)to find a specific character in a string
str = "i am studing python from gcu"
print(str.find("g"))
# Out:
# 11

# %%
#to count no of time repeat
str = "i am studing python from gcu"
print(str.count("i"))
# Out:
# 2

# %%
name = "maanik rao"
len = len(name)
print(len)
# Out:
# 10

# %%
str = "i am studing $ in gcu and my name is manik"
print(str.find("$"))
# Out:
# 13

# %%
name = input("my name is manik and i am studing in gcu")
len1 = "my name is manik and i am studing in gcu"
print(len(len1))
# Out:
# 40
